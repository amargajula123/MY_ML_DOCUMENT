# %%
Agenda :=
    
    1.Sopport Vector Machine("SVM")
    2.Sopport_Vector_Regresor("SVR").Algorithem

# %% [markdown]
# ## 1. Sopport_Vector_Machine(SVM)
#                 or
# ##   .. Sopport_Vector_Regressor(SVR) Algorithem

# %%
    1. "Sopport_Vector_Machine"(SVM)
    
    "Sopport_Vector_Machine"(SVM) sovle "classification"  and 
    "Regression" problem also,
    
     
What is "SVM" ?

  Ans :=
        
   "SVM" is nothing but "Sopport_Vector_Machine"(SVM) this can be used
to solve "Classification" and "Regression" problems stmts, if we are
soloving with this with "Classification" problem then we say it has 
"Sopport_Vector_Machine"("SVM")/"Sopport_Vector_Classifire"("SVC"),
if we are soloving with this with "Regression" problem then we say it
has ("SVR")"Sopport_Vector_Regresor"
        
        
        Aim :=
            we have to find out the "best hyperplane" along with the "Marginal"
            "planes".and there are two types.
            1."Hard Marginal Plane"
            2."Soft Marginal Plane"
            
        Obvously In a "real world" scenario its very deficult to create
        "Hard Marginal Plans".hardly in "few senrios" where all the points 
        are linearly "sapareteble". its Difucult in a reall world Senaorio
        b-coz datapoints will "Overlapped". its not so clearly saperaable
        by single line.
        
        
        
      It can solve "Binaly" and "Multy_class" Classifications.            
         
    
 let say i have dataset like this
    
       x2
       |
       | 
       |  • • /----->(this is called "Hyper_plane" if it has 3 "dimentions")       
       |• • •/  *  
       |• ••/ * * *            
       | ••/ *  *  *            • ----> data_points 1 
       |  /  * * *  *           * ----> data_points 2   
       | /  *   *  *
     --|/---------------->x1   
       |     
        

in "Support_Vector_Machine"(SVM) we try to create a "Best fit line"
that divede the two "data_points",
    
so here we try to come up with a 2 "dimentions" points or it can be
3 , 4 "dimentions" points

if it has 3 "dimentions" points we say this as "Hyper_plane"
   
what we are do in "Sopport_Vector_Machine" ?


        *"Sopport_Vector_Machine" creat a "Best fit line" but along with the
        "Best fit line" it will try to create other  "planes" near to
        "Best fit line" like "up" and "down" this "planes" are called 
        as "Marginal planes",
        
        *and this "Marginal planes" it will start from the "nearest point",
        and its alway paralel to the "Best fit line",
        
        "marginal plane 1" to "hyper parameter" distanse is equals to
        "marginal plane 2" to "hyper parameter" its same distace.
        
        but which ever "Marginal planes " has the "highest_distance"/max
        that will be selected in order to do the "Classification" problem,
        
        
       |         /---------------> this lane are called "Marginal planes"
       |        / / /------------>
       |       / / /     
       | • • •/ / /             middile one line called as "hyper plane"
       | • ••/ / / *            let say i have 2 categories of "data_points"
       |• • / / /*  *                            
       |•• / / /* *  *      
       | •/ / /*  * *           • ----> data_points 1
       | / / / * *              * ----> data_points 2     
      ε|/ /ε/            
       |----------------->              
                   
        
if we have "Maximum_distance" b/w "Marginal_planes" that basically means
we will devided the "lines"/"points" in a beutifull way,or we will be
"classify" the points in a beutifull way.

so when ever we "dont" have any "Errors"("missclassified points") means we
have a perfect "Marginal_planes" and "hyper_plane" this particuler condition
is bassically called as "Hard Marginal Plans".

let say you have Error like below 
      
       |         /---------------> this lane are called "Marginal planes"
       |        / / /------------>
       |       / / /     
       | • • •/ / /             middile one line called as "hyper plane"
       | • ••/ / / *            let say i have 2 categories of "data_points"
       |• • /⋆/ /*  *                            
       |•• /⋆/ /* *  *      
       | •/ / /*  * *           • ----> data_points 1
       | /⋆/ / * *              * ----> data_points 2     
      ε|/ /ε/                   ⋆  ----> error data_points
       |----------------->   
        
        
so when we have "Errors"("missclassified points") points in "Marginal_planes" 
that bassically called as "Soft Marginal Planes".

so In a "real world" scenario its very deficult to create "Hard Marginal Plans"
hardly in "few senrios" where all the points are linearly "sapareteble"
                    
So when ever there are "Errors"("missclassified points") how we find out the
this kind of lines ?

Ans :-
    So when ever there are "Errors"("missclassified points") we need to 
    know about some of the "hyper parameters".

_______________________________________________________________________
Aim of 'SVM' :=
            
    we have to find out the "best hyper plne" along with the 
    "marginal planes" and they are 2 types 
    
    1."hard_marginal_plane"
    2."soft_marginal_plane"
    obviously it is very defucult to get a "hard_marginal_plane"
    b-coz in a real world scenario our datapoints will be "overlaped"
    or it is not clearly saperatable by just a "lines"
________________________________________________________________________        
          
 

EX :=
    i have a data points like below:=
        
     we try to create a best fit line if it have 3 diamention
    we called it has "hyperplane"
    
    
if i write  y = mx + c  or y =θ0 + θ1x  or y = β0 + β1x
     
          
           ax+by+c =0 (:. equation of a "straite line")
            
            ax+by+c =0 == y = mx + c
        
           by = -ax - c
            
                   ax       c                     ax
            y = - ----- - ---- == y = mx + c  [:. --- = "coefficient" ] 
                    b       b                      b
                                                    c
                                              [:. ---- = "intercept" ]
                                                    b
            
            y = β0 + β1x
              ||
            y = WTx + b  == ax+by+c =0(:. equation of a "straite line")
            
            
  example                               (:.x1,x2,x3 3 "independent features")
        y = W1x1 + W2x2 + W3x3 + b      (:.w1,w2,w3 3 "independent coefficients")

  so i can show this  "y = WTx + b"   [ :. here b = 0 ] 
                                         [:."WTx" matrix "maltiplication" i am doing ]
    
                                       W1 
        y = WTx + b         -------->  W2 [x1 x2 x3]
            ||                         W3
        y = m1x1 + m2x2 + m3x3 + c       if i do "Transpose" then only i do 
            ||                            "matrix" "maltiplication"
        y = mx + c                     [:. here c = 0]
            ||                         m1 
        y = mTx + c         -------->  m2 [x1 x2 x3]
                                       m3 
            
we will try to find out  the "best fit line" with the "highest" 
"marginal_plane" distance so that we basically use to solve this
problem


what is "Sopport vectors" point?
Ans :=
    "Marginal planes" which actually drown with the help of "nearest points"
    to the "Desion Boundry"/"Hyperplane".these "points" are called as 
    "Sopport vectors". 
    
why this SVM called as "Sopport vectors machine" ?

Ans :-
    with the help of "Sopport vectors" points only we create "Marginal planes".
    this "Sopport vectors" points will tell like that "Best fit line" along
    with the "marginal planes" should come over here we are "sopporting" to do
    the "classification".
    
    
     
 let say i have "data_point" like below                    
                        
          \       y     
    * *    \      |
          \ \ \   |         🟍(4,4)
 *  *   *  \ \ \  |   *  *
       *    \ \ \ |  *   *             here b=0 its a "intercet" see if the
    *  *     \ \ \| * *   *           "Best fit line" passing through "origin"
      *   *  *\ \ \*    *  * *        so thats why b = 0
    --🟍--------\-\|\---------->x1
     (4,4)* *   \ | \   *  *  *
       * *  * *  \|\ \   *  * 
                  | \ \_(wTx+b=+k)i am gonna represent this(wTx1+b=+1)
                  |\ \
                  | \ \____ this represents(wTx+b=0)
                  |  \        
                  |   \
                       \_(wTx+b=-k)i am gonna represent this(wTx2+b=-1)
            
 let say i have "data_point" like below

       \
        *(-8) at this cordinate i get -8 
         \                              🔸at this point (x,y)foll "+ve values"  
          \       y                     🔸and this points are one "group"
    ♦ ♦    \      |                      ♦ at this point (x,y)foll "-ve values"
here all  \ \ \   |   🔸                 ♦ and this points are another "group"
points will\ \ \  | 🔸🔸  🟍(4,4) let say at this point   
have the -ve\ \ \ |  🔸  🔸  x,y
    ♦  ♦  ♦  \ \ \|  🔸 🔸🔸           🔸so all the "cordinates"(x,y) that 
      ♦  ♦  ♦ \ \ |  🔸  🔸             that come at this point {🔸} or at
    --🟍-------\-\-\---------->x          top of x,y line then this will "+ve values"
     (-4,0)♦    \ \ \   🔸 🔸🔸 
       x,y  ♦ ♦  \|\ \   🔸🔸 🔸
       ♦ ♦ ♦      | \ \_(wTx+b=+k)so i am gonna represent this(wTx+b=+1)  [:.k="Constant"]
                  |\ \   so" wTx+b=+1" will be become 🔸 +ve points "k" should be +ve
                  | \ \____ let say this line represents
                  |  \ \       like this --> 3x+2y+4=0
                  |   \
                       \_(wTx+b=-k)so i am gonna represent this(wTx+b=-1)
                          here "K" should be "-ve value". 
                        
                        
but in order to solve this problem we represent "K" as 1 be-coz if i
say "K" as  +1 it will goint to represent points +ve values, similarly
if i say "K" as -1  it will going to represent  -ve side values.
                     
                    
    here (-4,0) "x","y" are co-odinates(సమన్వయం)
                    
                            3(-4)+2(0)+4=0
                            = -8 "-ve value"
                            
    so with respect to "best fit line"(3x+2y+4=0) if i put x,y(-4,0)
    the value i am getting "-ve value"
                
                   (4,4) --> 3(4)+2(4)+4=0
                            = 24 "+ve value"
                
if 3x+2y+4=0 this "etire sumation" is >= 0 will getting at this🔸points
means these all are my "positive" values.

 "proof" :   x,y(4,4) -->3x+2y+4=0 3(4)+2(4)+4 = 24 >= 0
    
if 3x+2y+4=0 this "etire sumation" is <= 0 will getting at ♦ points
means these all are my "negative" values
  "proof" :   x,y(-4,0) -->3x+2y+4=0 3(-4)+2(0)+4 = -8 <= 0   
        
        
So we know "WTx+b=0"  every point that come above this line with respect
to equating this "hyper plane". iam going to get a +Ve Value or -Ve Value.
so we can use this approch to divinding this points.
        
        
check these "proofs" with this given link "calcuater"
        
        link := https://www.desmos.com/calculator
                
so if i get this "Best fit line" my task is to get the
"Marginal planes" on top of it

if i do 3x+2y+3 = 1 i get upper "marginal plane"
if i do 3x+2y+3 = -1 i get lower "marginal plane"

by "incresing" this values i can get  the distance b/w "marginal plane"it
becomes "high_distance" 
     3x+2y+4 = 2 
    
if i decrese the values i can get the distance b/w "marginal plane" it 
becomes "low_distance" .

     3x+2y+4 = -2 see in this calculater
                  link := https://www.desmos.com/calculator
                
if i "increase" this (3x+2y+3 = 2) "magnitude" by any same "number"
or myltiply (3x+2y+3 = 2)*10 = 30x+20y+30 = 20 then also this 
"marginal lines/planes" will be "same" .

similar to "-ve"(means -ve data points side) side also 
(3x+2y+3 = 2)*(10) = 30x+20y+30 = -20 chech"-ve" side so"- minus" is must


    
          \       y                   🔸at this point (x,y)foll "+ve values"
    * *    \      |
          \ \ \   |                    * at this point (x,y)foll "-ve values"
 *  *   *  \ \ \  |🔸 🔸
       *    \ \ \ | 🔸🔸 🔸             here b=0 its a "intercet" see if the
    *  *     \ \ \| 🔸 🔸 🔸            "Best fit line" passing through "origin"
      *   *  *\ \ \🔸🔸 🔸        so thats why b = 0
    -- --------\-\|\---------->x1
          * * * \ \ \🔸🔸🔸
         *  * *  \|\ \ 🔸🔸  🔸   
            *     \ \ \_wTx1+b=+1 we just represent as +1 b-coz +ve side comes
                  |\ \
                  | \ \____wTx+b=0
                  |  \        
                  |   \
                       \_wTx2+b=-1 we just represent as -1 b-coz -ve side comes.
                    
                    

now i need to find out the distance b/w 2 "Marginal_plane" in such a way that
it should be maximum.
    
             
this will calculate the distace B/W "Marginal_plane" 
       
    wTx1 + b = +1
    wTx2 + b = -1
   -     -     +  
--------------------
    wT(x1-x2)= 2       [:. W = "cofficient"]-->it has 2 things
                       so we know that W = "cofficient".
        
                     with respect to any "cofficient" it has 2 things
                      1. Magnitude
                      2. Vector.
                    
                we dont focuss on "Magnitude" be-coze if we "increse" the
                "Marginal planes" eqn by any "Magnitude" it almost same means
                the "distanse" will not chanege its same, at that we are just
                intrested wther it is "+ve" or "-ve",so i need to remove the 
                "Magnitude" so  i need to devide by "Magnitude" || W ||.
     -->          
      W          
                                   
    wT(x1-x2)     2                
    ---------  = -----    if i  devide both side of "Magnitude" of || W ||. 
     ||w||       ||w||    that bassically means i only remaining with W  "Vectors".
        
 What is Vector ?

sopose i have feature "AGE"---> have some "Magnitude" with "Deirection"

[:."Magnitude" is specifically with respect to "values".]

----------------------------------------------------------------------------
Examole : Scaler physical Quantities which can measser "lenght,mass,time," 
          which only has "Magnitude" but not "Directions"
        
          "Vectore physical quantity" which has both "Magnitude" and 
            "Directions"
------------------------------------------------------------------------

        
concider here like x1 = [x1i,x2i,x3i..xni] like that its one "set of points"
similarly
concider here like x2 = [x1i,x2i,x3i..xni] like that its "another set of points"


now our main "aim is increase" the "distance" (Vectore)
                                                         2 
by maximizing (wTx+b) w , b values its "maximize" this ----- values so
                                                       ||w|| 
by "Maximizing" that basically means we will get better "Marginal_planes"
    
   2
------- --> "maximize" it for get a best "marginal planes"
 ||w||     
    
      
                       2
        maximize     -----  
        (w,b)        ||W||
        
    
apart from that i write "stmt" likes

                    {+1 when    wTx+b≥1  this means "+ve" side "data_points" 
    such that  yi = {
                    {-1  when   wTx+b≤-1  this means "-ve" side "data_points" 
                
                   [:. constrant_1 = wTx+b≥1]
                   [:. constrant_2 = wTx+b≤-1]
                          
            so finaly "yi" we get, thats my output 
                   
for all the "Currect points"     
                   
this is my "Magnitude"*"constrant" ->  yi *(wTx+b≥1/wTx+b≤-1) this 
will be +ve side only b-coz 
                   
        so yi * ( wTx+b≥1/ wTx+b≤-1) >= 1 
    
    if i multiply 1 it will     1* wTx+b≥ (1 )>= 1
    if i multiply -1 it will   -1* wTx+b≤ (-1)>= 1
                   
                                 - * - = + only
                   
    so for all the "Currect points" my "Consttant" will be
    "(yi)*( wTx+b ) >= 1".
                   
for "miximizing"the "marginal_plans" distance we need to follow
this
                                 2              
    Our main is to "maximize"  ------                 
                      (w,b)     ||w||  

 similarly                   
for "minimizing"the "marginal_plans" distance we need to follow
this
                   
                    "Minimize"  ||w||
                     (w,b)      ------
                                  2
                   
why we need to "minimize" ?
  b-coz we have learn many "Cost_functions" in that many cases we have
 "minimized" our "Cost_function" and one more thing our "optimizers" will
 work in that way itself.
                   
 so i write final  "Cost_function" 
                   
                   
final "Cost_function"    
                     
                     "minimize"  ||w||
                       (w,b)     ----- ===> this works exctly work for 
                                    2       "hard marginal plane"
                                         b-coz in real worl senario we 
                                         dont get linearly "saperatable"
                                         "data_points" its very "overlaped"
                   

                   
So for "Soft marginal plan" where we may have "Missclassified points".
                   
final "Cost_function"  for "soft marginal plan "                   
                   
   minimize  ||w||      w  
     (w,b)   ----- + Ci ∑ ξi --> ξi is nothing but "summation" of the
               2       i=1      "distance" of the "marginal_error"/"Wrong_data_poins" 
                                 from the "Marginal_planes"
 
                   
what is "Marinal_Error" ? V.V.IMP
                   
    "ξi" basically says that with respect to "miss_classified" points
    it will claculate the "distance" from "miss_classified" to "marginal_planes".
    and will do the "sumation"(+) of (all point distance + sum)  all these "Distance",
                     
    so that it is saying that if your not able to get a "Best fit line" make sure
    that you "assume" some "distance" and saying that if this much "distance" is 
    there let it be, then also this "Best fit line" is fine and this is specifically
    called as "Marinal_Error",
                   
    it saying that in "real world scenario" we will not get "Best fit line"
    so what we do is where ever there is an "Error"(missclassified points)
    we caluculate the "distance", and it make sure that this "distanse" should
    also be there while creating a "marginal planes"/lines
                   
                   So we assume "ξ" value and this is kinda of
                   "hyper_parameter" 
                                      [:. "ξ" = "hyper_parameter"]
                   
                   
Cost function 
         minimize       ||w||        w
           (w,b)        ------- + Ci ∑  ξi  
                           2        i=1
                   
                [ :.C = again this "C" also a kind of "hyper_parameter"]
                   for "C" also we select different different numbers
                   
                   "C" specifies that how many "points" we want to "AVOID" 
                   "miss_classification"points/wrong_data points
                     
A "smalll" value of "C" means we are ok with more "missclassification"
    points.with respect to the "Soft marginal plane".
                     
A "large" value of "C" means we want to avoid "missclassification" points
at all cost with respect to the "Hard Marginal plane"
                     
 
With respect to "Classification"(SVM), we want to "AVOID"
misclassification points.
                     
With respect to "Regression"(SVM), we want to "ALLOW" some errors 
("misclassifications") in order to avoid overfitting.

In "Regression SVM", the goal is to find a "balance" between fitting 
the training data well. and avoiding "overfitting". Allowing some errors
helps to achieve this "balance"


        
                   
                          ||w||  
So if we only go with    ------- this, it will obviously work fine for
                            2     "Hard marginal plane", and with high distance
                                  of "marginal_plane" if dont add "Ci" and 
                                   "ξi"values parameters then it will not going to
                                    change. so it definatly there will be "Wrong_data"
                                    points
                   
        w      
     Ci ∑  ξi  }--> this is my "regularisation" parameter     
       i=1          "Hinge loss" in this 2 this things will come
                     1 is "C" and  "ξ"
    
                   
        :. "ξi" is says with respect to miss 
classified points(wrong data_points) we calculate the 
distance B/w wrong data points from marginal planes and
do the summetion of all the distance  this is specifically
called as "Marginal Error"     
                         
    :. "C" is also a "hyper parameter", this specifies how 
many "miss_classification" points we want to avoid / how many
(wrong data_points) we want to avoid .
        
        
        
        
 SVM has one amaging thing
        ^
        |              let say my datapoints will looks like this
        |      
        |     ● ● ● 
        |   ●  * *  ●      are we able to make "Best fit line" for this ?
        |  ●  *   *  ●      
        |   ●  * *  ●       Ans := yes  with the hepl of 
        |     ● ● ●                "Support Vector Machine" its posible there 
        |                           is somthing amezing in "SVM" which called as 
        |-------------------->      "SVM_kernals" SVM_kernal helps it converts 
                                   the "lower_dimension" into "higher_dimension"
                                  
        with the hlp of "Svm kernal" this 2_dimession will converted into 
        3 dimentions where in 
        
                     ^
                     |              
                     |      
             *  *    |     
           *      *  |      
             *  *    |     
       ______________|______                   
                     /-------------------->
               ● ●  /
              ●   ●/    when you have like this you can create
               ● ●/     hyper_plane like in shown
                 /  
                / 
               /
              /
# Out:
#   File "<tokenize>", line 37
#     if we solve this with  for a "classification" problems that
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
 1/1
# Out:
# 1.0

# %% [markdown]
# # Support Vector Regressor (SVR)

# %%
@Support Vector Regressor (SVR) :=
    if we i solve "Regression" problem statements  with respect to
    "Support Vector Machine" then it could be a "Support Vector Regressor"
    
    
                     wTxi
like 3x+2y+3=1      /   3x+2y+3=-1 so that the "marginal_plans" will be
     (wixi+ε)___   ● ___(wixi-ε)  "up" & "down" means -ve "data_points" side
            ●   / / /              +ve "data_points" side 
 house |   ξ|  / ● /     
 price | ●  |●/ / /    obviously we want to minimize  ||w||
       |  ● ●/ / /                by changing (w,b)     ------ = Cost_function
       |● ● /|○ /●                                         2
       | ● /ε/ /● ●         
       | ●/ / /●  ●            here i add a "constrant" that will be    
       | / ● /● ● ●                " |yi-WTxi| ≤ ε " [:.wTxi = ^y] 
       |/ / /● ●      
      ε| / /● ●   ●                            [:.^y = "predicted_points"]
       |/ /●● 
       |-/----○--------------> size 
       ε
        for this size(○) point my price will be at "best fit line"in  at this
        point(○) right so
            
        NOTE :=
            which points are on "best fit line" can be "predicted points"
        
What exactly the Marginal_plan in "Support Vector Regressor"(SVR) ?


"ε" is one value which will basically specifies one kind of a range
which is a kind of "hyper parameter". 


 in this |yi-WTxi| ≤ ε [:. yi   = "truth value"/point ]
                       [:. Wixi = ^y = "predicted_value"/point  ]
        
    Note :-
        what ever points that foll under "Marginal_planes" those points
are called as "truth_points".
  
so the differe B/w = yi-Wixi 

         "truth_point" - "predicted_point" = should be <= "epsilon"(ε)
         so that we get minimizes "maiginal_planes"
        
        Obviously the distance b/w "truth_point" and "predicted_point"
        will be 'less then' Epsilon("ε")
        b-coz "predicted points" are on "best fit line" but the "truth_points"
        will not in the "marginal_line" concider like this,
        
so its not like that we get all the points with in the "marginal_plans" 
only so apart from "ε"(epsilon) we will also add one more "parameter" 

                        
"Cost_function" :-
    
         "minimize"      ||w||       n
           (w,b)        ------- + Ci ∑ | ξi | 
                           2        i=1
            
           my "constrant" will 
         
            |yi-WTxi| ≤ ε + | ξi |  
            
                | ξi | --->"distance" of the "points" that are
                           away from the Epsilon("ε") line/marginale
                           lines.  
                        
                "Ci" -- > C is nothing but how many "missclassified"
                         points we need to "Allow" and again its kind
                        of "hper parameter"
                        
With respect to "Regression"(SVM), we want to "ALLOW" some errors 
("misclassifications") in order to avoid "Overfitting".

                    
so finally if we have Eta("ξi") distance and Epsilon("ε") distance
based on that it will calculate and "marginal_plans" distance.
      
        minmize ||w||/2  this is "Cost_function"
        (w,b)    
    
what is "Hinge loss" ?

        n     
     Ci ∑  ξi  }--> this is also called my "regularisation" parameter     
       i=1          in "SVM"(Support Vector Machine) actually its called
                    "Hinge loss" in this 2 things will come
                      1."C" , 2."ξ"
                     1 is "C" with respect to to avoid "miss_classified"
                    points
                    2 is "ξ" eta this is actually with respect to dostance of 
                    "truth_points" and summation of all the distances 
            
            
            
{IQ}what is the relationship B/W
"hingloss" "C" and "Cost_function", "λ" ?

Ans := relationship B/W "C" & "λ"
    "C" is inversally propotional to "λ"
    
          1 
    C α  -----  when C value "increases" λ "decreases"
          λ
        
{IQ}what is the relationship B/W "hingloss" ,"C" and
"Cost function" "slope"θ ?

Ans :=
    "C" and "slope" has a direct relationship
    when "C" value "increses" "Slop"(θ) also increses
    
    we Select "C" value with "hyper parameter tuning" with
        1.GridSearchCV
        2.RondomSearch
    
{IQ}what is the relationship B/W  ,"λ" and "Cost function" "slope"θ ?
     
Ans :-
    inversly propotional when "λ" increases "slope"(θ) decreses.
    

which is your favarate ML "Algotithem" ?

Ans:=
    there is no such my "fevorate Algorithem" as such each and
    every algorithem has this own "pross" and "corns",  i will 
    probably apply each and every algorithem for my problem
    statement, based on the "performance metrix" but with respect
    to "maths" the "algorithem" that i have understood completly
    like 100 persent is this specifiesc Algorithem,

# %%
in Linear Regression Cost_function :=
    
       Cost_function :=
                     1    m 
      J(θ0 , θ1) = -----  ∑ (yi - ^yi)² + λ (slope)² ->L2 "Regularisation"
                    2m   i=1                               (క్రమబద్ధీకరణ)

        
                     1    m 
      J(θ0 , θ1) = -----  ∑ (yi - yi)² + λ |slope| -> L1 "Regularisation"
                    2m   i=1            [:. λ = hyper parameter ]
        

            
in "Linear" , "Logistic"  what kind of "Regularisation"
you basically use?

Ans := "L1, L2 ,  Elasticnet,  Hing_loss"
   

{IQ}what is the difference B/W "loss" and "Cost function" ?

"loss" is only for 1 "data point"     "Cost_fun" is for "entire dataset"


           1                                   1   m 
lossfun = ----(y - y^)²            cost_fun = ---- ∑ (y - y^²)  
           2                                   2m i=1  
    
Can we use "Losso" in "Logistigc" regression ?

# %%
Agenda :=
    Start Machine Learning Project
    
    Requirement
    
    1. Github Account
    2. Heroku Account
    3. VS Code IDE
    4. GIT cli
    
    
Heroku :=
    when ever we create a app in heroku in backend it creates
    a "Vertual Machine" its linex based inside heroku cloud
    server for free perpose 512 MB will given to us
    
    
GIT pull :
    git pull is going to bring the "missing files" it will check
    fom the git hub system and which ever file is missing that will
    donloads
    
Version Controll System :
    benifit of Version Controll System it maintaines the 
    history if something went wrong what was the arlear version
    which is working perfectly you can go back to that previous
    one that is advantage of Version Controll System
    
Branching :=
    in git hub as many branches that we want we create it
    that is use of git creating branches 
    
   


Docker :=
    Docker helps us to our source code is portable its
    comfartable with every operating system bassically
    it provides "isolation" it isolate  run time environment
    Docker provides "portabulity" of our code to send
    something we need some "container"  with that we keep
    the like code are something to make sure that it is 
    running properly in live environment that we wanted to port 
    
    Image concept in Docker

Container :=
    Container is like a vartuvalisation of a hard ware 
    thgroug you can install "OS" and all the libraries
    and then you can run your command to lunch your 
    application 
Docker Image:=
    set up command to create docker image 
    OS operating system we need and set the "working"
    "DIR" and create "Vertual environment" and
    activate the environment  once its activated i will
    install requirements.txt lanch "python" app.py to
    creation of docker image we need this all things 
    and Docker should be insalled we can save this image
    in docker hub

# %%
Agenda :=
    
FSDS june12 :=
    1. create a flask app [Hellow World]
    2. write a docker file for flask application
    3. create github action for CI/CD
    4. Heroku app for flask deployment
    5. create Structure for ML project
    6. Build Machine Learning pipeline

# %%
deployment projcet :
    
    clone with "CS code " and "Git hub" repo then your file
    save and run internally in your system 
    
    the set the "CONDA" environment
    
    and activate the vertual environment
    
    create requirements.txt file
    
    and after running the applivation over cloud
    send changes to the git hub 
    
 .gitignore :=
    this ".gitignore" is the file which contine files
    and folder name thats should not be maitain by "git"
    .gitignore the file and folder which is mentioned inside
    ".gitignore " file
    
    
git add . <file name> :=
    this is command it could add the particuler name that
    you mentioned that will be add we are adding files 
    to inside the git so that if there is any modifications
    and it maintains the file "version" the latest one if your
    not gonna add file its not maintain "version"
    "git add ." is also add all the files 
    
git status :=
    per example your create a file its not avile in git

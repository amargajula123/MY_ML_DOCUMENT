# %%
Agend

1. Gradiant Boost
2. XGboost
3. Unsupervised ML --> K means clustring
                   --> 
    
@Gradiant Boost :=
    Gradiant boost is used for Classification problem and 
    Regration problem
    
i have some features 
    
    Exp       Degree          Salary
    
    
f(n) = Base model + h0(x1)  


@XGboost Clasifier :=
    
    salary          credit       Approval   Residal
    
     <=50K            B              0       -0.5           
     <=50K            G              1        0.5
     <=50K            G              1        0.5
     > 50K            B              0       -0.5 
     > 50k            G              1        0.5
     > 50K            N              1        0.5
     <=50K            N              0       -0.5 
    
step : 1 :=
        Constract Base Model 
        
        ouput of this base model is 0.5 
        
step : 2 :=
        Cponstract Tree with Root
        
        [-0.5,0.5,0.5,-0.5,0.5,0.5,-0.5]
                  salary
                    |
            |----------------|
            |                |
    [-0.5,0.5,0.5,-0.5]  [-0.5,0.5,0.5]
    
step : 4 :=
        Gain = 0 + 0.33 - 0.142 = 0.188
        
        
    xgboost : base model        
        
@XGboost Regressor :=
    
    Exp       gap      salary   res1
    2         yes        40K    -11
    2.5       yes        42k    -9
    3          no        52K     1
    4          no        60K     9
    4.5       yes        62K     11
    
    
    
    basa mode ---> 51K
    
    constract dession tree 
    
    [-11,-9,1,9,11]
       exp                     [-11-9+1+9+11]/n+1 = 1/6 =0.166
        |                       similari weight = 121/2 =60.5
 |-------------------|        similari weight = -9+1+9+11/2 =28.8
[-11]          [-9,1,9,11]    gain = 60.5+28.8-0.166 = 89.134
   
    
step : 2 :                  (Resida)
        siilarity weight = -------------
                             Pr(1-Pr)+
            
                             (Resida)
                        = ------------------
                           no.of residal +
                        
                
                
                
Un_superwised Machine Leaning :=
    
    the mager 
    
    lets concider i am runnina a mall 
             MAll <-------- New project 
        
    
K Means Clustring :=
    aim :=
 
Heirarichal Mean Clustring :=
    how to find how many clusters in your graph
    
    we need to the longest vertical line such that
    none of the horizontal line passed away
